# %%
import data_utils
import numpy as np
import math

# %%
def filter_dataset(dataset, top_k):
    # add the pad, end, oov chars
    results = []
    for sequence in dataset:
        results.append([x for x in sequence if x < top_k])
    return np.array(results)


def vectorize_sequences(sequences, dimension):
    results = np.zeros((len(sequences), dimension), dtype=np.float32)
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results


def to_one_hot(labels, num_classes):
    results = np.zeros((len(labels), num_classes))
    for i, l in enumerate(labels):
        results[i, l] = 1.
    return results

# %%
batch_size = 1000
num_batches = 10
min_index = 0
max_index = 10001

# %%
for i in range(11):
    n = i % num_batches + 1
    
    d = min_index + (n + 1)* batch_size
    print(d)
    print(d < max_index)
# Out:
# 2000
# True
# 3000
# True
# 4000
# True
# 5000
# True
# 6000
# True
# 7000
# True
# 8000
# True
# 9000
# True
# 10000
# True
# 11000
# False
# 2000
# True

# %%
def data_generator(x, y, x_dimension, y_dimension,
                   batch_size, min_index=None, max_index=None, shuffle=False):
    
    if not min_index:
        min_index = 0
    if not max_index:
        max_index = len(x)
    
    num_batches = (max_index - min_index) // batch_size + 1
    num_classes = len(set(y))

    i = 0
    while True:
        n = i % num_batches
        i += 1
        if (min_index + (n+1) * batch_size) < max_index:
            print('then from {} to {}'.format(min_index + n*batch_size, min_index + (n+1)*batch_size))
            yield (
                vectorize_sequences(
                    x[min_index + n*batch_size: min_index + (n+1)*batch_size],
                    x_dimension),
                to_one_hot(
                    y[min_index + n*batch_size: min_index + (n+1)*batch_size],
                    num_classes)
            )
        else:
            i = 0
            print('else from {} to {}'.format(min_index + n*batch_size, max_index))
            yield (
                vectorize_sequences(
                    x[min_index + n*batch_size: max_index],
                    x_dimension),
                to_one_hot(
                    y[min_index + n*batch_size: max_index], num_classes
                )
            )
        if shuffle:
            indexes = np.array(range(min_index, max_index))
            np.random.shuffle(indexes)
            x[min_index: max_index] = x[indexes]
            y[min_index: max_index] = y[indexes]

# %%
dataset = np.load('../../data/dataset/atti_dataset.npz')

x_train = dataset['x_train']
y_train = dataset['y_train']

x_test = dataset['x_test']
y_test = dataset['y_test']

# %%
dimensions = 10000

# %%
x_train = data_utils.filter_dataset(x_train, dimensions)
x_test = data_utils.filter_dataset(x_test, dimensions)

# %%
batch_size = 128
num_classes = len(set(y_train))
train_val_split = math.ceil(len(x_train) * 0.8)

# %%
batch_size
# Out:
# 128

# %%
train_generator = data_generator(
    x_train, y_train, dimensions, num_classes, batch_size, 0, train_val_split, True
)
val_generator = data_generator(
    x_train, y_train, dimensions, num_classes, batch_size, train_val_split, len(x_train), True  
)

# %%
train_val_split
# Out:
# 115478

# %%
train_val_split / batch_size
# Out:
# 902.171875

# %%
train_epochs = train_val_split // batch_size + 1

for i in range(train_epochs + 10):
    next(train_generator)
# Out:
# then from 0 to 128
# then from 128 to 256
# then from 256 to 384
# then from 384 to 512
# then from 512 to 640
# then from 640 to 768
# then from 768 to 896
# then from 896 to 1024
# then from 1024 to 1152
# then from 1152 to 1280
# then from 1280 to 1408
# then from 1408 to 1536
# then from 1536 to 1664
# then from 1664 to 1792
# then from 1792 to 1920
# then from 1920 to 2048
# then from 2048 to 2176
# then from 2176 to 2304
# then from 2304 to 2432
# then from 2432 to 2560
# then from 2560 to 2688
# then from 2688 to 2816
# then from 2816 to 2944
# then from 2944 to 3072
# then from 3072 to 3200
# then from 3200 to 3328
# then from 3328 to 3456
# then from 3456 to 3584
# then from 3584 to 3712
# then from 3712 to 3840
# then from 3840 to 3968
# then from 3968 to 4096
# then from 4096 to 4224
# then from 4224 to 4352
# then from 4352 to 4480
# then from 4480 to 4608
# then from 4608 to 4736
# then from 4736 to 4864
# then from 4864 to 4992
# then from 4992 to 5120
# then from 5120 to 5248
# then from 5248 to 5376
# then from 5376 to 5504
# then from 5504 to 5632
# then from 5632 to 5760
# then from 5760 to 5888
# then from 5888 to 6016
# then from 6016 to 6144
# then from 6144 to 6272
# then from 6272 to 6400
# then from 6400 to 6528
# then from 6528 to 6656
# then from 6656 to 6784
# then from 6784 to 6912
# then from 6912 to 7040
# then from 7040 to 7168
# then from 7168 to 7296
# then from 7296 to 7424
# then from 7424 to 7552
# then from 7552 to 7680
# then from 7680 to 7808
# then from 7808 to 7936
# then from 7936 to 8064
# then from 8064 to 8192
# then from 8192 to 8320
# then from 8320 to 8448
# then from 8448 to 8576
# then from 8576 to 8704
# then from 8704 to 8832
# then from 8832 to 8960
# then from 8960 to 9088
# then from 9088 to 9216
# then from 9216 to 9344
# then from 9344 to 9472
# then from 9472 to 9600
# then from 9600 to 9728
# then from 9728 to 9856
# then from 9856 to 9984
# then from 9984 to 10112
# then from 10112 to 10240
# then from 10240 to 10368
# then from 10368 to 10496
# then from 10496 to 10624
# then from 10624 to 10752
# then from 10752 to 10880
# then from 10880 to 11008
# then from 11008 to 11136
# then from 11136 to 11264
# then from 11264 to 11392
# then from 11392 to 11520
# then from 11520 to 11648
# then from 11648 to 11776
# then from 11776 to 11904
# then from 11904 to 12032
# then from 12032 to 12160
# then from 12160 to 12288
# then from 12288 to 12416
# then from 12416 to 12544
# then from 12544 to 12672
# then from 12672 to 12800
# then from 12800 to 12928
# then from 12928 to 13056
# then from 13056 to 13184
# then from 13184 to 13312
# then from 13312 to 13440
# then from 13440 to 13568
# then from 13568 to 13696
# then from 13696 to 13824
# then from 13824 to 13952
# then from 13952 to 14080
# then from 14080 to 14208
# then from 14208 to 14336
# then from 14336 to 14464
# then from 14464 to 14592
# then from 14592 to 14720
# then from 14720 to 14848
# then from 14848 to 14976
# then from 14976 to 15104
# then from 15104 to 15232
# then from 15232 to 15360
# then from 15360 to 15488
# then from 15488 to 15616
# then from 15616 to 15744
# then from 15744 to 15872
# then from 15872 to 16000
# then from 16000 to 16128
# then from 16128 to 16256
# then from 16256 to 16384
# then from 16384 to 16512
# then from 16512 to 16640
# then from 16640 to 16768
# then from 16768 to 16896
# then from 16896 to 17024
# then from 17024 to 17152
# then from 17152 to 17280
# then from 17280 to 17408
# then from 17408 to 17536
# then from 17536 to 17664
# then from 17664 to 17792
# then from 17792 to 17920
# then from 17920 to 18048
# then from 18048 to 18176
# then from 18176 to 18304
# then from 18304 to 18432
# then from 18432 to 18560
# then from 18560 to 18688
# then from 18688 to 18816
# then from 18816 to 18944
# then from 18944 to 19072
# then from 19072 to 19200
# then from 19200 to 19328
# then from 19328 to 19456
# then from 19456 to 19584
# then from 19584 to 19712
# then from 19712 to 19840
# then from 19840 to 19968
# then from 19968 to 20096
# then from 20096 to 20224
# then from 20224 to 20352
# then from 20352 to 20480
# then from 20480 to 20608
# then from 20608 to 20736
# then from 20736 to 20864
# then from 20864 to 20992
# then from 20992 to 21120
# then from 21120 to 21248
# then from 21248 to 21376
# then from 21376 to 21504
# then from 21504 to 21632
# then from 21632 to 21760
# then from 21760 to 21888
# then from 21888 to 22016
# then from 22016 to 22144
# then from 22144 to 22272
# then from 22272 to 22400
# then from 22400 to 22528
# then from 22528 to 22656
# then from 22656 to 22784
# then from 22784 to 22912
# then from 22912 to 23040
# then from 23040 to 23168
# then from 23168 to 23296
# then from 23296 to 23424
# then from 23424 to 23552
# then from 23552 to 23680
# then from 23680 to 23808
# then from 23808 to 23936
# then from 23936 to 24064
# then from 24064 to 24192
# then from 24192 to 24320
# then from 24320 to 24448
# then from 24448 to 24576
# then from 24576 to 24704
# then from 24704 to 24832
# then from 24832 to 24960
# then from 24960 to 25088
# then from 25088 to 25216
# then from 25216 to 25344
# then from 25344 to 25472
# then from 25472 to 25600
# then from 25600 to 25728
# then from 25728 to 25856
# then from 25856 to 25984
# then from 25984 to 26112
# then from 26112 to 26240
# then from 26240 to 26368
# then from 26368 to 26496
# then from 26496 to 26624
# then from 26624 to 26752
# then from 26752 to 26880
# then from 26880 to 27008
# then from 27008 to 27136
# then from 27136 to 27264
# then from 27264 to 27392
# then from 27392 to 27520
# then from 27520 to 27648
# then from 27648 to 27776
# then from 27776 to 27904
# then from 27904 to 28032
# then from 28032 to 28160
# then from 28160 to 28288
# then from 28288 to 28416
# then from 28416 to 28544
# then from 28544 to 28672
# then from 28672 to 28800
# then from 28800 to 28928
# then from 28928 to 29056
# then from 29056 to 29184
# then from 29184 to 29312
# then from 29312 to 29440
# then from 29440 to 29568
# then from 29568 to 29696
# then from 29696 to 29824
# then from 29824 to 29952
# then from 29952 to 30080
# then from 30080 to 30208
# then from 30208 to 30336
# then from 30336 to 30464
# then from 30464 to 30592
# then from 30592 to 30720
# then from 30720 to 30848
# then from 30848 to 30976
# then from 30976 to 31104
# then from 31104 to 31232
# then from 31232 to 31360
# then from 31360 to 31488
# then from 31488 to 31616
# then from 31616 to 31744
# then from 31744 to 31872
# then from 31872 to 32000
# then from 32000 to 32128
# then from 32128 to 32256
# then from 32256 to 32384
# then from 32384 to 32512
# then from 32512 to 32640
# then from 32640 to 32768
# then from 32768 to 32896
# then from 32896 to 33024
# then from 33024 to 33152
# then from 33152 to 33280
# then from 33280 to 33408
# then from 33408 to 33536
# then from 33536 to 33664
# then from 33664 to 33792
# then from 33792 to 33920
# then from 33920 to 34048
# then from 34048 to 34176
# then from 34176 to 34304
# then from 34304 to 34432
# then from 34432 to 34560
# then from 34560 to 34688
# then from 34688 to 34816
# then from 34816 to 34944
# then from 34944 to 35072
# then from 35072 to 35200
# then from 35200 to 35328
# then from 35328 to 35456
# then from 35456 to 35584
# then from 35584 to 35712
# then from 35712 to 35840
# then from 35840 to 35968
# then from 35968 to 36096
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-df978eaf8cbd> in <module>()
#       2
#       3 for i in range(train_epochs + 10):
# ----> 4     next(train_generator)
#
# <ipython-input-19-a3795b94ac4c> in data_generator(x, y, x_dimension, y_dimension, batch_size, min_index, max_index, shuffle)
#      36             )
#      37         if shuffle:
# ---> 38             indexes = np.array(range(min_index, max_index))
#      39             np.random.shuffle(indexes)
#      40             x[min_index: max_index] = x[indexes]
#
# KeyboardInterrupt:

# %%
val_epochs = (len(x_train) - train_val_split) // batch_size + 1
print(val_epochs)
print(val_epochs * batch_size, len(x_train) - train_val_split)
# Out:
# 226
# 28928 28869

# %%
for i in range(val_epochs):
    x,y = next(val_generator)
# Out:
# then from 115478 to 115606
# then from 115606 to 115734
# then from 115734 to 115862
# then from 115862 to 115990
# then from 115990 to 116118
# then from 116118 to 116246
# then from 116246 to 116374
# then from 116374 to 116502
# then from 116502 to 116630
# then from 116630 to 116758
# then from 116758 to 116886
# then from 116886 to 117014
# then from 117014 to 117142
# then from 117142 to 117270
# then from 117270 to 117398
# then from 117398 to 117526
# then from 117526 to 117654
# then from 117654 to 117782
# then from 117782 to 117910
# then from 117910 to 118038
# then from 118038 to 118166
# then from 118166 to 118294
# then from 118294 to 118422
# then from 118422 to 118550
# then from 118550 to 118678
# then from 118678 to 118806
# then from 118806 to 118934
# then from 118934 to 119062
# then from 119062 to 119190
# then from 119190 to 119318
# then from 119318 to 119446
# then from 119446 to 119574
# then from 119574 to 119702
# then from 119702 to 119830
# then from 119830 to 119958
# then from 119958 to 120086
# then from 120086 to 120214
# then from 120214 to 120342
# then from 120342 to 120470
# then from 120470 to 120598
# then from 120598 to 120726
# then from 120726 to 120854
# then from 120854 to 120982
# then from 120982 to 121110
# then from 121110 to 121238
# then from 121238 to 121366
# then from 121366 to 121494
# then from 121494 to 121622
# then from 121622 to 121750
# then from 121750 to 121878
# then from 121878 to 122006
# then from 122006 to 122134
# then from 122134 to 122262
# then from 122262 to 122390
# then from 122390 to 122518
# then from 122518 to 122646
# then from 122646 to 122774
# then from 122774 to 122902
# then from 122902 to 123030
# then from 123030 to 123158
# then from 123158 to 123286
# then from 123286 to 123414
# then from 123414 to 123542
# then from 123542 to 123670
# then from 123670 to 123798
# then from 123798 to 123926
# then from 123926 to 124054
# then from 124054 to 124182
# then from 124182 to 124310
# then from 124310 to 124438
# then from 124438 to 124566
# then from 124566 to 124694
# then from 124694 to 124822
# then from 124822 to 124950
# then from 124950 to 125078
# then from 125078 to 125206
# then from 125206 to 125334
# then from 125334 to 125462
# then from 125462 to 125590
# then from 125590 to 125718
# then from 125718 to 125846
# then from 125846 to 125974
# then from 125974 to 126102
# then from 126102 to 126230
# then from 126230 to 126358
# then from 126358 to 126486
# then from 126486 to 126614
# then from 126614 to 126742
# then from 126742 to 126870
# then from 126870 to 126998
# then from 126998 to 127126
# then from 127126 to 127254
# then from 127254 to 127382
# then from 127382 to 127510
# then from 127510 to 127638
# then from 127638 to 127766
# then from 127766 to 127894
# then from 127894 to 128022
# then from 128022 to 128150
# then from 128150 to 128278
# then from 128278 to 128406
# then from 128406 to 128534
# then from 128534 to 128662
# then from 128662 to 128790
# then from 128790 to 128918
# then from 128918 to 129046
# then from 129046 to 129174
# then from 129174 to 129302
# then from 129302 to 129430
# then from 129430 to 129558
# then from 129558 to 129686
# then from 129686 to 129814
# then from 129814 to 129942
# then from 129942 to 130070
# then from 130070 to 130198
# then from 130198 to 130326
# then from 130326 to 130454
# then from 130454 to 130582
# then from 130582 to 130710
# then from 130710 to 130838
# then from 130838 to 130966
# then from 130966 to 131094
# then from 131094 to 131222
# then from 131222 to 131350
# then from 131350 to 131478
# then from 131478 to 131606
# then from 131606 to 131734
# then from 131734 to 131862
# then from 131862 to 131990
# then from 131990 to 132118
# then from 132118 to 132246
# then from 132246 to 132374
# then from 132374 to 132502
# then from 132502 to 132630
# then from 132630 to 132758
# then from 132758 to 132886
# then from 132886 to 133014
# then from 133014 to 133142
# then from 133142 to 133270
# then from 133270 to 133398
# then from 133398 to 133526
# then from 133526 to 133654
# then from 133654 to 133782
# then from 133782 to 133910
# then from 133910 to 134038
# then from 134038 to 134166
# then from 134166 to 134294
# then from 134294 to 134422
# then from 134422 to 134550
# then from 134550 to 134678
# then from 134678 to 134806
# then from 134806 to 134934
# then from 134934 to 135062
# then from 135062 to 135190
# then from 135190 to 135318
# then from 135318 to 135446
# then from 135446 to 135574
# then from 135574 to 135702
# then from 135702 to 135830
# then from 135830 to 135958
# then from 135958 to 136086
# then from 136086 to 136214
# then from 136214 to 136342
# then from 136342 to 136470
# then from 136470 to 136598
# then from 136598 to 136726
# then from 136726 to 136854
# then from 136854 to 136982
# then from 136982 to 137110
# then from 137110 to 137238
# then from 137238 to 137366
# then from 137366 to 137494
# then from 137494 to 137622
# then from 137622 to 137750
# then from 137750 to 137878
# then from 137878 to 138006
# then from 138006 to 138134
# then from 138134 to 138262
# then from 138262 to 138390
# then from 138390 to 138518
# then from 138518 to 138646
# then from 138646 to 138774
# then from 138774 to 138902
# then from 138902 to 139030
# then from 139030 to 139158
# then from 139158 to 139286
# then from 139286 to 139414
# then from 139414 to 139542
# then from 139542 to 139670
# then from 139670 to 139798
# then from 139798 to 139926
# then from 139926 to 140054
# then from 140054 to 140182
# then from 140182 to 140310
# then from 140310 to 140438
# then from 140438 to 140566
# then from 140566 to 140694
# then from 140694 to 140822
# then from 140822 to 140950
# then from 140950 to 141078
# then from 141078 to 141206
# then from 141206 to 141334
# then from 141334 to 141462
# then from 141462 to 141590
# then from 141590 to 141718
# then from 141718 to 141846
# then from 141846 to 141974
# then from 141974 to 142102
# then from 142102 to 142230
# then from 142230 to 142358
# then from 142358 to 142486
# then from 142486 to 142614
# then from 142614 to 142742
# then from 142742 to 142870
# then from 142870 to 142998
# then from 142998 to 143126
# then from 143126 to 143254
# then from 143254 to 143382
# then from 143382 to 143510
# then from 143510 to 143638
# then from 143638 to 143766
# then from 143766 to 143894
# then from 143894 to 144022
# then from 144022 to 144150
# then from 144150 to 144278
# else from 144278 to 144347

# %%
len(x_train)
# Out:
# 144347
