# %%
import urllib3
import json
import random
import time
import os
import logging
import requests

import numpy as np
import pandas as pd

# %%
to_save_path = '../data/'

# %% [markdown]
# # Crawl Documents
#
# In this notebook we show how we extracted the documents from [Regione Toscana](http://www.regione.toscana.it/bancadati/atti/)
#
# ## Get Typology Documents

# %%
url = 'http://www.regione.toscana.it/bancadati/atti/getTipologiaDelibere.json'

r = requests.get(url)

# %%
df_type_delibere = pd.DataFrame(r.json()['getTipologiaDelibere']['Tipologia'])
df_type_delibere
# Out:
#      ID                               NOME
# 0    DG
# 1   P07                      COMUNICAZIONE
# 2   P05                          DECISIONE
# 3   P06             DECISIONE DI CONTROLLO
# 4   DEL                           DELIBERA
# 5   P09              DOCUMENTO PRELIMINARE
# 6   P03  PROPOSTA DI DELIBERAZIONE AL C.R.
# 7   P01                  PROPOSTA DI LEGGE
# 8   P02            PROPOSTA DI REGOLAMENTO
# 9   P04    PROPOSTA DI RISOLUZIONE AL C.R.
# 10  P08                REGOLAMENTO INTERNO

# %%
df_type_delibere.to_csv(to_save_path + "tipologia_delibere.csv", index=False)
r.close()

# %% [markdown]
# ## Get The Name of Dirigential Offices

# %%
url = 'http://www.regione.toscana.it/bancadati/atti/getDg.json'
r = requests.get(url)

# %%
df_struttura = pd.DataFrame(r.json()['getDg']['Struttura'])
df_struttura.sort_values(by=['ID'])
# Out:
#        ID                                               NOME
# 10  01025  DIPARTIMENTO ORGANIZZAZIONE                   ...
# 9   01027  DIPARTIMENTO BILANCIO E FINANZE               ...
# 1   01923  AVVOCATURA REGIONALE                          ...
# 14  01928  DIPARTIMENTO PRESIDENZA AFFARI LEGISLATIVI E G...
# 11  01931  DIPARTIMENTO ORGANIZZAZIONE E RISORSE         ...
# 16  01934  DIPARTIMENTO SVILUPPO ECONOMICO               ...
# 13  01937  DIPARTIMENTO POLITICHE TERRITORIALI E AMBIENTA...
# 15  01943  DIPARTIMENTO SALUTE E POLITICHE SOLIDARIETA   ...
# 12  01946  DIPARTIMENTO POLITICHE FORMATIVE E BENI CULTUR...
# 42  02090  UFFICI DEL GENIO CIVILE                       ...
# 8   50000  D.G. PRESIDENZA                               ...
# 28  50001  DIREZIONE GENERALE ORGANIZZAZIONE E SISTEMA IN...
# 24  50002  DIREZIONE GENERALE BILANCIO E FINANZE         ...
# 33  50003  DIREZIONE GENERALE SVILUPPO ECONOMICO         ...
# 31  50004  DIREZIONE GENERALE POLITICHE TERRITORIALI E AM...
# 26  50005  DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLIT...
# 29  50006  DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E...
# 2   50007  D.G.  AVVOCATURA                              ...
# 32  50026  DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI ...
# 41  50044    SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO
# 6   50069  D.G. ORGANIZZAZIONE E RISORSE                 ...
# 3   50073  D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SV...
# 4   50079  D.G. DIRITTI DI CITTADINANZA E COESIONE SOCIAL...
# 7   50083  D.G. POLITICHE TERRITORIALI, AMBIENTALI E PER ...
# 5   50102  D.G. ORGANIZZAZIONE                           ...
# 25  50112  DIREZIONE GENERALE DIREZIONE GENERALE DELLA GI...
# 17  50113  DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED IST...
# 38  50114                DIREZIONE PROGRAMMAZIONE E BILANCIO
# 36  50115     DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI
# 23  50116  DIREZIONE DIRITTI DI CITTADINANZA E COESIONE S...
# 18  50117            DIREZIONE AGRICOLTURA E SVILUPPO RURALE
# 19  50118                      DIREZIONE AMBIENTE ED ENERGIA
# 22  50119     DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE
# 37  50121  DIREZIONE POLITICHE MOBILITA', INFRASTRUTTURE ...
# 39  50122  DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE
# 20  50123                     DIREZIONE ATTIVITA' PRODUTTIVE
# 21  50124                        DIREZIONE CULTURA E RICERCA
# 34  50125                  DIREZIONE ISTRUZIONE E FORMAZIONE
# 35  50127                                   DIREZIONE LAVORO
# 27  50200          DIREZIONE GENERALE GOVERNO DEL TERRITORIO
# 30  50201  DIREZIONE GENERALE POLITICHE MOBILITA', INFRAS...
# 40  50202  POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CL...
# 0   99999                                       ALTRI UFFICI

# %%
df_struttura.to_csv(to_save_path + 'dg_struttura.csv', index=False)

# %% [markdown]
# ## Download "Atti Giunta"
#
# parameters and base url

# %%
act_types = {
    'atti_dirigenti': 'DMON', 
    'atti_presidente': 'DPG',
    'atti_giunta': 'DAD'
}

year = 2017
start = 0
num = 200
from_number = 0
to_number = 200

base_url = "http://www.regione.toscana.it/bancadati/search?site=atti&client=fend_json&output=xml_no_dtd&getfields=*&ulang=it&ie=UTF-8&proxystylesheet=fend_json&start={:d}&num={:d}&filter=0&rc=1&q=inmeta%3AID_TIPO_PRATICA%3{}+AND+inmeta%3ADATA_ATTO%3A{}-01-01..{}-12-31+AND+inmeta%3ANUMERO%3A{}..{}+AND+inmeta%3AALLEGATO_DESCRIZIONE%3Dvoid&sort=meta%3ACODICE_PRATICA%3AA"

# %%
example_url = base_url.format(start, num, act_types['atti_giunta'], year, year, from_number, to_number)
example_url
# Out:
# 'http://www.regione.toscana.it/bancadati/search?site=atti&client=fend_json&output=xml_no_dtd&getfields=*&ulang=it&ie=UTF-8&proxystylesheet=fend_json&start=0&num=200&filter=0&rc=1&q=inmeta%3AID_TIPO_PRATICA%3DAD+AND+inmeta%3ADATA_ATTO%3A2017-01-01..2017-12-31+AND+inmeta%3ANUMERO%3A0..200+AND+inmeta%3AALLEGATO_DESCRIZIONE%3Dvoid&sort=meta%3ACODICE_PRATICA%3AA'

# %%
r = requests.get(example_url)

# %%
r.status_code
# Out:
# 200

# %%
data = r.json()

# %%
def navigate_json_path(json, path):
    for e in path:
        json = json[e]
    return json

# %%
def extract_data(json_data, json_path=['GSP', 'RES', 'R']):
    data = navigate_json_path(json_data, json_path)
    results = []
    for row in data:
        results.append(row['MT'])
    return results

# %%
def unwrap_list(x):
    if type(x) == list:
        return x[0]
    else:
        return x

# %%
results = extract_data(data)
df_giunta = pd.DataFrame(results)

df_giunta = df_giunta.applymap(unwrap_list)
df_giunta.head()
# Out:
#   ALLEGATO_DESCRIZIONE ALLEGATO_ID ALLEGATO_TIPO_PUBBL  \
# 0                 void           0                void
# 1                 void           0                void
# 2                 void           0                void
# 3                 void           0                void
# 4                 void           0                void
#
#                     CODICE_PRATICA Creator   DATA_ATTO  \
# 0  201701100000012016DG00000001750     NaN  2017-01-10
# 1  201701100000012016DG00000001765     NaN  2017-01-10
# 2  201701100000022016DG00000001712     NaN  2017-01-10
# 3  201701100000022016DG00000001751     NaN  2017-01-10
# 4  201701100000032016DG00000001731     NaN  2017-01-10
#
#                                          DESCRIZIONE  DESCRIZIONE_TIPO_ATTO  \
# 0  Atto soggetto a pubblicazione integrale (PBURT...               Delibera
# 1  Atto soggetto a pubblicazione su Banca Dati (PBD)  Documento preliminare
# 2  Atto soggetto a pubblicazione su Banca Dati (PBD)      Proposta di legge
# 3  Atto soggetto a pubblicazione su Banca Dati (PBD)               Delibera
# 4  Atto soggetto a pubblicazione integrale (PBURT...               Delibera
#
#   DESCRIZIONE_TIPO_PRATICA                   DT_UTENTE  \
# 0        Atto della giunta  2017-01-12 14:10:26.851966
# 1        Atto della giunta  2017-01-12 14:19:38.101904
# 2        Atto della giunta  2017-01-12 12:59:18.461721
# 3        Atto della giunta  2017-01-17 10:42:31.904961
# 4        Atto della giunta  2017-01-12 14:11:44.029312
#
#             ...                                                       OGGETTO  \
# 0           ...             Procedimento di verifica di Assoggettabilità S...
# 1           ...             Piano di Tutela delle Acque della Toscana (ex ...
# 2           ...             Attività europee e di rilievo internazionale d...
# 3           ...             Impugnativa alla Corte Costituzionale del Decr...
# 4           ...             Approvazione e formalizzazione, ai sensi e per...
#
#       PERSONA STATUS                             TESTO_RISPOSTA UFFICIO_AC  \
# 0         140      2               Delibera n. 1 del 10/01/2017      00000
# 1        1404      2  Documento preliminare n. 1 del 10/01/2017      00000
# 2  140#@#1408      2      Proposta di legge n. 2 del 10/01/2017      00000
# 3         140      2               Delibera n. 2 del 10/01/2017      00000
# 4        1401      2               Delibera n. 3 del 10/01/2017      00000
#
#   UFFICIO_DG UFFICIO_SE            creation date             publisher  \
# 0      50118      04788  D:20170112141020+01'00'  iText 2.1.7 by 1T3XT
# 1      50119      05121  D:20170112141937+01'00'  iText 2.1.7 by 1T3XT
# 2      50112      02002  D:20170112125916+01'00'  iText 2.1.7 by 1T3XT
# 3      50007      00000  D:20170117104213+01'00'  iText 2.1.7 by 1T3XT
# 4      50113      02511  D:20170112141141+01'00'  iText 2.1.7 by 1T3XT
#
#              revision date
# 0  D:20170112141020+01'00'
# 1  D:20170112141937+01'00'
# 2  D:20170112125916+01'00'
# 3  D:20170117104213+01'00'
# 4  D:20170112141141+01'00'
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Download Atti Presidente

# %%
example_url = base_url.format(start, num, act_types['atti_presidente'], year, year, from_number, to_number)
example_url
# Out:
# 'http://www.regione.toscana.it/bancadati/search?site=atti&client=fend_json&output=xml_no_dtd&getfields=*&ulang=it&ie=UTF-8&proxystylesheet=fend_json&start=0&num=200&filter=0&rc=1&q=inmeta%3AID_TIPO_PRATICA%3DPG+AND+inmeta%3ADATA_ATTO%3A2017-01-01..2017-12-31+AND+inmeta%3ANUMERO%3A0..200+AND+inmeta%3AALLEGATO_DESCRIZIONE%3Dvoid&sort=meta%3ACODICE_PRATICA%3AA'

# %%
r = requests.get(example_url)
data = r.json()

# %%
results = extract_data(data)    

df_atti = pd.DataFrame(results)

df_atti = df_atti.applymap(unwrap_list)
df_atti.head()
# Out:
#   ALLEGATO_DESCRIZIONE ALLEGATO_ID ALLEGATO_TIPO_PUBBL        CODICE_PRATICA  \
# 0                 void           0                void  20170000012017AP0013
# 1                 void           0                void  20170000012017AP0208
# 2                 void           0                void  20170000022017AP0001
# 3                 void           0                void  20170000022017AP0084
# 4                 void           0                void  20170000032017AP0149
#
#   Creator   DATA_ATTO                                        DESCRIZIONE  \
# 0     NaN  2017-02-21  Atto soggetto a pubblicazione integrale (PBURT...
# 1     NaN  2017-01-11  Atto soggetto a pubblicazione integrale (PBURT...
# 2     NaN  2017-01-16  Atto soggetto a pubblicazione integrale (PBURT...
# 3     NaN  2017-06-29  Atto soggetto a pubblicazione integrale (PBURT...
# 4     NaN  2017-10-02  Atto soggetto a pubblicazione integrale (PBURT...
#
#       DESCRIZIONE_TIPO_ATTO DESCRIZIONE_TIPO_PRATICA  \
# 0  Ordinanza del Presidente      Atto del presidente
# 1    Decreto del Presidente      Atto del presidente
# 2    Decreto del Presidente      Atto del presidente
# 3  Ordinanza del Presidente      Atto del presidente
# 4  Ordinanza del Presidente      Atto del presidente
#
#                     DT_UTENTE           ...             \
# 0  2017-02-21 11:49:34.865008           ...
# 1   2017-01-11 16:05:21.09736           ...
# 2  2017-01-16 08:59:10.325308           ...
# 3  2017-06-29 12:02:03.974215           ...
# 4   2017-10-02 15:18:03.09593           ...
#
#                                              OGGETTO PERSONA STATUS  \
# 0  Art. 191 del Dlgs 152/06. Discarica in localit...    void      2
# 1  Commissione di concorso per n. 1 posto di Diri...    void      2
# 2  COMMISSIONE DI DEGUSTAZIONE VINI TCA - PRATO. ...    void      2
# 3  Reiterazione dell'Ordinanza contingibile ed ur...    void      2
# 4  Reiterazione dell'ordinanza contingibile ed ur...    void      2
#
#                                  TESTO_RISPOSTA UFFICIO_AC UFFICIO_DG  \
# 0  Ordinanza del Presidente n. 1 del 21/02/2017      00000      50118
# 1    Decreto del Presidente n. 1 del 11/01/2017      00000      50113
# 2    Decreto del Presidente n. 2 del 16/01/2017      00000      50113
# 3  Ordinanza del Presidente n. 2 del 29/06/2017      00000      50118
# 4  Ordinanza del Presidente n. 3 del 02/10/2017      00000      50118
#
#   UFFICIO_SE            creation date             publisher  \
# 0      05108  D:20170221114933+01'00'  iText 2.1.7 by 1T3XT
# 1      00000  D:20170111160519+01'00'  iText 2.1.7 by 1T3XT
# 2      00000  D:20170116085907+01'00'  iText 2.1.7 by 1T3XT
# 3      05866  D:20170629120201+02'00'  iText 2.1.7 by 1T3XT
# 4      05984  D:20171002151801+02'00'  iText 2.1.7 by 1T3XT
#
#              revision date
# 0  D:20170221114933+01'00'
# 1  D:20170111160519+01'00'
# 2  D:20170116085907+01'00'
# 3  D:20170629120201+02'00'
# 4  D:20171002151801+02'00'
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Download Atti Dei Dirigenti

# %%
example_url = base_url.format(start, num, act_types['atti_dirigenti'], year, year, from_number, to_number)
example_url
# Out:
# 'http://www.regione.toscana.it/bancadati/search?site=atti&client=fend_json&output=xml_no_dtd&getfields=*&ulang=it&ie=UTF-8&proxystylesheet=fend_json&start=0&num=200&filter=0&rc=1&q=inmeta%3AID_TIPO_PRATICA%3DMON+AND+inmeta%3ADATA_ATTO%3A2017-01-01..2017-12-31+AND+inmeta%3ANUMERO%3A0..200+AND+inmeta%3AALLEGATO_DESCRIZIONE%3Dvoid&sort=meta%3ACODICE_PRATICA%3AA'

# %%
r = requests.get(example_url)
data = r.json()

# %%
results = extract_data(data)    

df_dirigenti = pd.DataFrame(results)

df_dirigenti = df_dirigenti.applymap(unwrap_list)
df_dirigenti.head()
# Out:
#   ALLEGATO_DESCRIZIONE ALLEGATO_ID ALLEGATO_TIPO_PUBBL  \
# 0                 void           0                void
# 1                 void           0                void
# 2                 void           0                void
# 3                 void           0                void
# 4                 void           0                void
#
#                 CODICE_PRATICA Creator   DATA_ATTO  \
# 0  20170000012016AD00000017891     NaN  2017-01-02
# 1  20170000022016AD00000017976     NaN  2017-01-02
# 2  20170000032016AD00000017981     NaN  2017-01-02
# 3  20170000042016AD00000017962     NaN  2017-01-02
# 4  20170000052017AD00000000003     NaN  2017-01-02
#
#                            DESCRIZIONE  \
# 0  Atto pubblicato su Banca Dati (PBD)
# 1  Atto pubblicato su Banca Dati (PBD)
# 2  Atto pubblicato su Banca Dati (PBD)
# 3  Atto pubblicato su Banca Dati (PBD)
# 4  Atto pubblicato su Banca Dati (PBD)
#
#                       DESCRIZIONE_TIPO_ATTO DESCRIZIONE_TIPO_PRATICA  \
# 0  Decreto non soggetto a controllo interno       Atto dei dirigenti
# 1  Decreto non soggetto a controllo interno       Atto dei dirigenti
# 2  Decreto non soggetto a controllo interno       Atto dei dirigenti
# 3  Decreto non soggetto a controllo interno       Atto dei dirigenti
# 4  Decreto non soggetto a controllo interno       Atto dei dirigenti
#
#                     DT_UTENTE           ...             \
# 0  2017-01-02 11:34:32.955471           ...
# 1  2017-01-02 11:43:31.001254           ...
# 2  2017-01-02 11:51:51.747645           ...
# 3  2017-01-02 12:17:27.972291           ...
# 4  2017-01-02 12:20:28.627011           ...
#
#                                              OGGETTO PERSONA STATUS  \
# 0  D.lgs. 150/2012 - Piano nazionale per l'uso so...  005595      2
# 1  VEZZOSI MAURO E FILIPPO S.n.c. , stabilimento ...  018285      2
# 2  Approvazione di verbale integrativo al verbale...  018491      2
# 3  F.lli Gori di Gori Giovanni & Mario s.n.c. (AR...  018285      2
# 4  Ditta Morescalchi Srl, attività di officina me...  018285      2
#
#                 TESTO_RISPOSTA UFFICIO_AC UFFICIO_DG UFFICIO_SE  \
# 0  Decreto n. 1 del 02/01/2017      00000      50117      05015
# 1  Decreto n. 2 del 02/01/2017      00000      50118      05106
# 2  Decreto n. 3 del 02/01/2017      00000      50115      04196
# 3  Decreto n. 4 del 02/01/2017      00000      50118      05106
# 4  Decreto n. 5 del 02/01/2017      00000      50118      05106
#
#              creation date                                          publisher  \
# 0  D:20170102102315+01'00'  iText 2.1.7 by 1T3XT; modified using iText® 5....
# 1  D:20170102110602+01'00'  iText 2.1.7 by 1T3XT; modified using iText® 5....
# 2  D:20170102104836+01'00'  iText 2.1.7 by 1T3XT; modified using iText® 5....
# 3  D:20170102104842+01'00'  iText 2.1.7 by 1T3XT; modified using iText® 5....
# 4  D:20170102111011+01'00'  iText 2.1.7 by 1T3XT; modified using iText® 5....
#
#              revision date
# 0  D:20170102113149+01'00'
# 1  D:20170102114220+01'00'
# 2  D:20170102115042+01'00'
# 3  D:20170102121505+01'00'
# 4  D:20170102122007+01'00'
#
# [5 rows x 24 columns]
