# %%
import json
import pandas as pd
import glob

pd.options.display.max_columns = 999

# %%
def unwrap_list(x):
    if type(x) == list:
        return x[0]
    else:
        return x

# %% [markdown]
# ## Merging Atti Dirigenti

# %%
columns_to_keep = ['CODICE_PRATICA', 'DATA_ATTO', 'DESCRIZIONE',
       'DESCRIZIONE_TIPO_ATTO', 'DESCRIZIONE_TIPO_PRATICA',
       'ID_TIPO_PRATICA', 'LINK_CONTENUTO_BINARIO',
       'OGGETTO', 'PERSONA', 'STATUS', 'UFFICIO_AC',
       'UFFICIO_DG', 'UFFICIO_SE', 'publisher']

def load_atti(source_path):
    files = sorted(glob.glob(source_path))
    results = []
    for f in files:
        df = pd.read_json(f)
        df = df.applymap(unwrap_list)
        df = df[columns_to_keep]
        results.append(df)
    return pd.concat(results)

# %%
atti_dirigenti_path = '../data/atti_dirigenti/data-*'
df_atti_dirigenti = load_atti(atti_dirigenti_path)

# %%
print(df_atti_dirigenti.publisher.shape)
df_atti_dirigenti.head()
# Out:
# (156239,)
#                 CODICE_PRATICA   DATA_ATTO  \
# 0  20000000011999AD00000005121  2000-01-04
# 1  20000000021999AD00000005123  2000-01-04
# 2  20000000031999AD00000005018  2000-01-04
# 3  20000000041999AD00000005116  2000-01-04
# 4  20000000051999AD00000005127  2000-01-04
#
#                                   DESCRIZIONE  \
# 0  Atto soggetto a pubblicazione per estratto
# 1  Atto soggetto a pubblicazione per estratto
# 2  Atto soggetto a pubblicazione per estratto
# 3  Atto soggetto a pubblicazione per estratto
# 4  Atto soggetto a pubblicazione per estratto
#
#                     DESCRIZIONE_TIPO_ATTO DESCRIZIONE_TIPO_PRATICA  \
# 0  Decreto soggetto a controllo congiunto       Atto dei dirigenti
# 1  Decreto soggetto a controllo congiunto       Atto dei dirigenti
# 2  Decreto soggetto a controllo congiunto       Atto dei dirigenti
# 3  Decreto soggetto a controllo congiunto       Atto dei dirigenti
# 4  Decreto soggetto a controllo congiunto       Atto dei dirigenti
#
#   ID_TIPO_PRATICA                             LINK_CONTENUTO_BINARIO  \
# 0             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 1             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 2             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 3             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 4             MON  http://www.regione.toscana.it/bancadati/atti/C...
#
#                                              OGGETTO PERSONA STATUS  \
# 0  DIP. ALESSANDRO ANNUNZIATI (MATR. 14117). ASPE...  004744      2
# 1  DIP. GIOVANNI ORLANDINI (MATR. 14311). ASPETTA...  004744      2
# 2  DIP. LEONELLO TOCCAFONDI. CONGEDO STRAORDINARI...  004744      2
# 3  DIPENDENTI REGIONALI DIVERSI. CONGEDO STRAORDI...  004744      2
# 4  DIP. SILVIA LORENZI (MATR. 13366). CONGEDO STR...  004744      2
#
#   UFFICIO_AC UFFICIO_DG UFFICIO_SE                         publisher
# 0      04246      01931      04516  Acrobat PDFWriter4.0 per Windows
# 1      04246      01931      04516  Acrobat PDFWriter4.0 per Windows
# 2      04246      01931      04516  Acrobat PDFWriter4.0 per Windows
# 3      04246      01931      04516  Acrobat PDFWriter4.0 per Windows
# 4      04246      01931      04516  Acrobat PDFWriter4.0 per Windows

# %%
df_atti_dirigenti.to_pickle('../data/atti_dirigenti.pkl')

# %% [markdown]
# ## Merging Atti Giunta

# %%
atti_giunta_path = '../data/atti_giunta/data*'
df_atti_giunta = load_atti(atti_giunta_path)

# %%
print(df_atti_giunta.shape)
df_atti_giunta.head()
# Out:
# (24243, 14)
#                     CODICE_PRATICA   DATA_ATTO  \
# 0  199905310000051999DG00000000459  1999-05-31
# 1  199905310000061999DG00000000460  1999-05-31
# 2  199905310000231999DG00000000486  1999-05-31
# 3  199905310000241999DG00000000432  1999-05-31
# 4  1999053100002619990205DG0000392  1999-05-31
#
#                       DESCRIZIONE              DESCRIZIONE_TIPO_ATTO  \
# 0  Atto non soggetto a pubblicità  Proposta di deliberazione al C.R.
# 1  Atto non soggetto a pubblicità  Proposta di deliberazione al C.R.
# 2  Atto non soggetto a pubblicità  Proposta di deliberazione al C.R.
# 3  Atto non soggetto a pubblicità                          Decisione
# 4  Atto non soggetto a pubblicità  Proposta di deliberazione al C.R.
#
#   DESCRIZIONE_TIPO_PRATICA ID_TIPO_PRATICA  \
# 0        Atto della giunta              AD
# 1        Atto della giunta              AD
# 2        Atto della giunta              AD
# 3        Atto della giunta              AD
# 4        Atto della giunta              AD
#
#                               LINK_CONTENUTO_BINARIO  \
# 0  http://www.regione.toscana.it/bancadati/atti/C...
# 1  http://www.regione.toscana.it/bancadati/atti/C...
# 2  http://www.regione.toscana.it/bancadati/atti/C...
# 3  http://www.regione.toscana.it/bancadati/atti/C...
# 4  http://www.regione.toscana.it/bancadati/atti/C...
#
#                                              OGGETTO PERSONA STATUS  \
# 0  APPROVAZIONE BILANCIO CONSUNTIVO ANNO 1998 DEL...    1003      2
# 1  ART.20 L.R.49/86 - APPROVAZIONE BILANCIO DI PR...    1003      2
# 2  PIANO SANITARIO REGIONALE 1999-2001 - PIANO SA...    1009      2
# 3  L.R. 15/93 - PRESA D ATTO DEL RENDICONTO GENER...    1010      2
# 4  Asilo Infantile Cappelli e Grazini con sede le...    1011      2
#
#   UFFICIO_AC UFFICIO_DG UFFICIO_SE        publisher
# 0          0      01937          0  LibreOffice 5.1
# 1          0      01937          0  LibreOffice 5.1
# 2          0      01943          0  LibreOffice 5.1
# 3      04321      01934          0  LibreOffice 5.1
# 4      05125      01943             LibreOffice 5.1

# %%
df_atti_giunta.to_pickle('../data/atti_giunta.pkl')

# %% [markdown]
# ## Merging Atti Presidente

# %%
atti_presidente_path = '../data/atti_presidente/data*'
df_atti_presidente = load_atti(atti_presidente_path)

# %%
print(df_atti_presidente.shape)
df_atti_presidente.head()
# Out:
# (3899, 14)
#          CODICE_PRATICA   DATA_ATTO  \
# 0  20020000012002AP0059  2002-05-10
# 1  20020000022002AP0111  2002-06-25
# 2  20020000032002AP0112  2002-06-25
# 3  20020000042002AP0118  2002-06-26
# 4  20020000052002AP0139  2002-07-22
#
#                                   DESCRIZIONE     DESCRIZIONE_TIPO_ATTO  \
# 0     Atto soggetto a pubblicazione integrale  Ordinanza del Presidente
# 1     Atto soggetto a pubblicazione integrale  Ordinanza del Presidente
# 2     Atto soggetto a pubblicazione integrale  Ordinanza del Presidente
# 3  Atto soggetto a pubblicazione per estratto  Ordinanza del Presidente
# 4     Atto soggetto a pubblicazione integrale  Ordinanza del Presidente
#
#   DESCRIZIONE_TIPO_PRATICA ID_TIPO_PRATICA  \
# 0      Atto del presidente              PG
# 1      Atto del presidente              PG
# 2      Atto del presidente              PG
# 3      Atto del presidente              PG
# 4      Atto del presidente              PG
#
#                               LINK_CONTENUTO_BINARIO  \
# 0  http://www.regione.toscana.it/bancadati/atti/C...
# 1  http://www.regione.toscana.it/bancadati/atti/C...
# 2  http://www.regione.toscana.it/bancadati/atti/C...
# 3  http://www.regione.toscana.it/bancadati/atti/C...
# 4  http://www.regione.toscana.it/bancadati/atti/C...
#
#                                              OGGETTO PERSONA STATUS  \
# 0  Misure sanitarie contro la malattia vescicolar...    void      2
# 1  Misure sanitarie contro la malattia vescicolar...    void      2
# 2  Misure sanitarie per malattia da Newcastle. Re...    void      2
# 3  Art. 25 L. 64/74 - Violazione alle norme di ed...    void      2
# 4  Revoca misure sanitarie contro la malattia ves...    void      2
#
#   UFFICIO_AC UFFICIO_DG UFFICIO_SE                          publisher
# 0      00944      01943          0  Acrobat PDFWriter4.05 per Windows
# 1      00944      01943          0  Acrobat PDFWriter4.05 per Windows
# 2      00944      01943          0  Acrobat PDFWriter4.05 per Windows
# 3      01232      02090      01289  Acrobat PDFWriter4.05 per Windows
# 4      00944      01943          0  Acrobat PDFWriter4.05 per Windows

# %%
df_atti_presidente.to_pickle('../data/atti_presidente.pkl')

# %% [markdown]
# ## Merge the 3 datasets

# %%
df_atti = pd.concat([df_atti_dirigenti, df_atti_giunta, df_atti_presidente])
df_atti.shape
# Out:
# (184381, 14)

# %%
df_atti.to_pickle('../data/atti.pkl')
