# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.ioff()
import seaborn as sns
sns.set_style("whitegrid")
from scipy import stats, integrate
from scipy.stats import kendalltau

import warnings
warnings.filterwarnings('ignore')

# %matplotlib notebook

plt.rcParams['figure.figsize'] = (8, 8)

# %%
def label_rotation(ax, angle):
    for tick in ax.get_xticklabels():
        tick.set_rotation(45)
    return ax

# %%
df = pd.read_pickle('../data/atti-dirigenti.pkl')
df.shape
# Out:
# (153206, 13)

# %%
df.head(5)
# Out:
#                 CODICE_PRATICA  DATA_ATTO DESCRIZIONE_TIPO_PRATICA ID_TIPO  \
# 0  20160140002016AD00000017201 2016-12-19       Atto dei dirigenti     ADN
# 1  20160140012016AD00000017466 2016-12-21       Atto dei dirigenti     ADN
# 2  20160140022016AD00000017198 2016-12-19       Atto dei dirigenti     ADN
# 3  20160140032016AD00000017208 2016-12-19       Atto dei dirigenti     ADN
# 4  20160140042016AD00000017268 2016-12-20       Atto dei dirigenti     ADN
#
#   ID_TIPO_PRATICA                             LINK_CONTENUTO_BINARIO  \
# 0             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 1             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 2             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 3             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 4             MON  http://www.regione.toscana.it/bancadati/atti/C...
#
#                                              OGGETTO PERSONA  STATUS  \
# 0  DGR 968/07 e s.m.i. Accreditamento degli organ...  013910       2
# 1  REG. CEE 2080/92 - AIUTI ALLE MISURE FORESTALI...  005595       2
# 2  Servizi autorizzati ex art.14 L.R. 42/98 "Norm...  019075       2
# 3  L.R. 1/2006, DCR 3/2012, L.R. 1/2015 art.29, c...  020415       2
# 4  L.R. n. 87/1997 - Pubblicazione sul BURT dell'...  010826       2
#
#   UFFICIO_AC UFFICIO_DG UFFICIO_SE  \
# 0      00000      50125      05873
# 1      00000      50117      05015
# 2      00000      50121      04838
# 3      00000      50117      05018
# 4      00000      50116      05895
#
#                                           DETAIL_URL
# 0  http://www.regione.toscana.it/bancadati/atti/D...
# 1  http://www.regione.toscana.it/bancadati/atti/D...
# 2  http://www.regione.toscana.it/bancadati/atti/D...
# 3  http://www.regione.toscana.it/bancadati/atti/D...
# 4  http://www.regione.toscana.it/bancadati/atti/D...

# %% [markdown]
# Let us deescribe the features

# %%
df.describe(include='all')
# Out:
#                      CODICE_PRATICA            DATA_ATTO  \
# count                        153206               153206
# unique                       152455                 4556
# top     20020056002002AD00000006355  2016-07-19 00:00:00
# freq                              2                  258
# first                           NaN  2000-01-04 00:00:00
# last                            NaN  2018-03-09 00:00:00
# mean                            NaN                  NaN
# std                             NaN                  NaN
# min                             NaN                  NaN
# 25%                             NaN                  NaN
# 50%                             NaN                  NaN
# 75%                             NaN                  NaN
# max                             NaN                  NaN
#
#        DESCRIZIONE_TIPO_PRATICA ID_TIPO ID_TIPO_PRATICA  \
# count                    153206  153206          153206
# unique                        1       4               1
# top          Atto dei dirigenti      AD             MON
# freq                     153206   62925          153206
# first                       NaN     NaN             NaN
# last                        NaN     NaN             NaN
# mean                        NaN     NaN             NaN
# std                         NaN     NaN             NaN
# min                         NaN     NaN             NaN
# 25%                         NaN     NaN             NaN
# 50%                         NaN     NaN             NaN
# 75%                         NaN     NaN             NaN
# max                         NaN     NaN             NaN
#
#                                    LINK_CONTENUTO_BINARIO  \
# count                                              153206
# unique                                             130730
# top     http://www.regione.toscana.it/bancadati/atti/C...
# freq                                                21826
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   OGGETTO PERSONA  \
# count                                              153206  153206
# unique                                             148031     388
# top     L.r. 55/2006 - "Interventi in favore delle vit...  005549
# freq                                                  417    8022
# first                                                 NaN     NaN
# last                                                  NaN     NaN
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#                STATUS UFFICIO_AC UFFICIO_DG UFFICIO_SE  \
# count   153206.000000     153206     153206     153206
# unique            NaN        353         43        855
# top               NaN      00000      50073          0
# freq              NaN      44878      13890      29191
# first             NaN        NaN        NaN        NaN
# last              NaN        NaN        NaN        NaN
# mean         2.000509        NaN        NaN        NaN
# std          0.140910        NaN        NaN        NaN
# min          2.000000        NaN        NaN        NaN
# 25%          2.000000        NaN        NaN        NaN
# 50%          2.000000        NaN        NaN        NaN
# 75%          2.000000        NaN        NaN        NaN
# max         41.000000        NaN        NaN        NaN
#
#                                                DETAIL_URL
# count                                              153206
# unique                                             152455
# top     http://www.regione.toscana.it/bancadati/atti/D...
# freq                                                    2
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# From the outcome of the describe we can notice that:
# 1. there are some duplicates by `CODICE_PRATICA`
# 2. the person 005549 occurs 8022 time as signer for acts while the most frequent office is 50073
#
# As tasks:
# - we are going to remove duplicates for `CODICE_PRATICA`
#
# #### Drop duplicates by `CODICE_PRATICA`

# %%
df_drop = df.drop_duplicates(subset=['CODICE_PRATICA'])
df = df_drop

# %% [markdown]
# ### Replace office id with names
#
# Let us merge the index with the name of the offices.

# %%
df_office = pd.read_json('../data/strutture_processed.json')
df_office['ID'] = df_office['ID'].astype(str)

# %%
id_office_map = df_office.set_index(df_office['ID']).drop(['ID'], axis=1).to_dict()['NOME']

# %% [markdown]
# We check what are the offices that do not have a match

# %%
not_matched = []
matched = []
matched_id_name = {}

for i in df['UFFICIO_DG'].unique():
    if i in id_office_map:
        matched.append(id_office_map[i])
        matched_id_name[i] = id_office_map[i]
    else:
        not_matched.append(i)

# %% [markdown]
# From the name of the offices it is interesting to see that there are:
# - offices that changed the name
# - there are some abbreviations
#
# we will create a replacement map to deal with these problems

# %%
matched_id_name
# Out:
# {'50125': 'DIREZIONE ISTRUZIONE E FORMAZIONE',
#  '50117': 'DIREZIONE AGRICOLTURA E SVILUPPO RURALE',
#  '50121': "DIREZIONE POLITICHE MOBILITA', INFRASTRUTTURE E TRASPORTO PUBBLICO LOCALE",
#  '50116': 'DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SOCIALE',
#  '50123': "DIREZIONE ATTIVITA' PRODUTTIVE",
#  '50118': 'DIREZIONE AMBIENTE ED ENERGIA',
#  '50112': 'DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIUNTA REGIONALE',
#  '50119': 'DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE',
#  '50124': 'DIREZIONE CULTURA E RICERCA',
#  '50115': 'DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI',
#  '50044': 'SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO',
#  '50007': 'D.G.  AVVOCATURA                                      ',
#  '50127': 'DIREZIONE LAVORO',
#  '50114': 'DIREZIONE PROGRAMMAZIONE E BILANCIO',
#  '50122': 'DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE',
#  '50113': 'DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTITUZIONALI',
#  '50001': 'DIREZIONE GENERALE ORGANIZZAZIONE E SISTEMA INFORMATIV',
#  '50004': 'DIREZIONE GENERALE POLITICHE TERRITORIALI E AMBIENTALI',
#  '50002': 'DIREZIONE GENERALE BILANCIO E FINANZE                 ',
#  '50003': 'DIREZIONE GENERALE SVILUPPO ECONOMICO                 ',
#  '50005': 'DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITICHE DI ',
#  '50000': 'D.G. PRESIDENZA                                       ',
#  '50006': 'DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ATTIVIT',
#  '50073': "D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVILUPPO D",
#  '50083': 'D.G. POLITICHE TERRITORIALI, AMBIENTALI E PER LA MOBIL',
#  '50079': 'D.G. DIRITTI DI CITTADINANZA E COESIONE SOCIALE       ',
#  '50102': 'D.G. ORGANIZZAZIONE                                   ',
#  '50069': 'D.G. ORGANIZZAZIONE E RISORSE                         ',
#  '99999': 'ALTRI UFFICI',
#  '50201': "DIREZIONE GENERALE POLITICHE MOBILITA', INFRASTRUTTURE E TRASPORTO PUBBLICO LOCALE",
#  '50202': 'POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLIMATICI',
#  '50200': 'DIREZIONE GENERALE GOVERNO DEL TERRITORIO',
#  '50026': 'DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI DELLA GIUNTA'}

# %%
to_replace = {
    '50001': '50115',
    '50069': '50115',
    '50102': '50115',
    '50083': '50004',
    '50079': '50116',
    '50118': '50202',
    '50121': '50201'
}

# %% [markdown]
# - We can replace the offices with wrong names
# - we reaplace the codes with the canonical names of the offices

# %%
df_replaced = df
df_replaced['UFFICIO_DG'] = df['UFFICIO_DG'].replace(to_replace)

# %%
df= df_replaced.replace(matched_id_name)

# %%
df.head()
# Out:
#                 CODICE_PRATICA  DATA_ATTO DESCRIZIONE_TIPO_PRATICA ID_TIPO  \
# 0  20160140002016AD00000017201 2016-12-19       Atto dei dirigenti     ADN
# 1  20160140012016AD00000017466 2016-12-21       Atto dei dirigenti     ADN
# 2  20160140022016AD00000017198 2016-12-19       Atto dei dirigenti     ADN
# 3  20160140032016AD00000017208 2016-12-19       Atto dei dirigenti     ADN
# 4  20160140042016AD00000017268 2016-12-20       Atto dei dirigenti     ADN
#
#   ID_TIPO_PRATICA                             LINK_CONTENUTO_BINARIO  \
# 0             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 1             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 2             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 3             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 4             MON  http://www.regione.toscana.it/bancadati/atti/C...
#
#                                              OGGETTO PERSONA  STATUS  \
# 0  DGR 968/07 e s.m.i. Accreditamento degli organ...  013910       2
# 1  REG. CEE 2080/92 - AIUTI ALLE MISURE FORESTALI...  005595       2
# 2  Servizi autorizzati ex art.14 L.R. 42/98 "Norm...  019075       2
# 3  L.R. 1/2006, DCR 3/2012, L.R. 1/2015 art.29, c...  020415       2
# 4  L.R. n. 87/1997 - Pubblicazione sul BURT dell'...  010826       2
#
#   UFFICIO_AC                                         UFFICIO_DG UFFICIO_SE  \
# 0      00000                  DIREZIONE ISTRUZIONE E FORMAZIONE      05873
# 1      00000            DIREZIONE AGRICOLTURA E SVILUPPO RURALE      05015
# 2      00000  DIREZIONE GENERALE POLITICHE MOBILITA', INFRAS...      04838
# 3      00000            DIREZIONE AGRICOLTURA E SVILUPPO RURALE      05018
# 4      00000  DIREZIONE DIRITTI DI CITTADINANZA E COESIONE S...      05895
#
#                                           DETAIL_URL
# 0  http://www.regione.toscana.it/bancadati/atti/D...
# 1  http://www.regione.toscana.it/bancadati/atti/D...
# 2  http://www.regione.toscana.it/bancadati/atti/D...
# 3  http://www.regione.toscana.it/bancadati/atti/D...
# 4  http://www.regione.toscana.it/bancadati/atti/D...

# %% [markdown]
# ## Data Exploration
#
# As first step we want visualize the distrubition of the acts per:
# - year
# - employee
# - office
#
# ### Acts Per Year

# %%
acts_per_year = df.groupby([df['DATA_ATTO'].dt.year])['CODICE_PRATICA'].count()

fig, ax = plt.subplots()
sns.barplot(acts_per_year.index, acts_per_year.values, palette="BuGn_d", ax=ax)
label_rotation(ax, 45)
fig.set_size_inches(10,6)
plt.title('Distribution Acts per Year')
plt.show(fig)

# %% [markdown]
# The distribution of the acts per year shows that there is an increase of acts for the years 2016 and 2017.
# This is because in 2016 there was a grouping of the regional districts.
#
# From another point of view is interesting to see the distribution of acts per person.
#
# ### Acts Per Employee

# %%
print('acts distribution per person')
acts_per_person = df.groupby([df['PERSONA']])['CODICE_PRATICA'].count().sort_values(ascending=False)
print(acts_per_person[:10])
# Out:
# acts distribution per person
# PERSONA
# 005549    7989
# 020411    4316
# 005045    3816
# 015534    3778
# 007505    3060
# 014002    2645
# 013692    2103
# 005642    2013
# 005070    1943
# 017792    1836
# Name: CODICE_PRATICA, dtype: int64

# %% [markdown]
# We scale the values in the range [0:1] to make the visualization more clear and plot the distribution.

# %%
acts_per_person_scaled = (acts_per_person - acts_per_person.min()) / (acts_per_person.max() - acts_per_person.min())

fig, ax = plt.subplots()
sns.distplot(acts_per_person_scaled.values, kde=False, ax=ax, fit=stats.beta)
fig.set_size_inches(10,6)
plt.title('Distribution Acts per Person compared with a Beta')
plt.show()

# %% [markdown]
# Here we can see that the distribution follows a beta distribution, which means that there is a

# %% [markdown]
# ### Distribution of Acts per Office
#
# from here we can see what are the most active offices

# %%
df_act_office = df.groupby(df['UFFICIO_DG'])['CODICE_PRATICA'].count()
df_act_office /= df_act_office.max()
top = df_act_office.sort_values(ascending=False)[:20]
plt.pie(top, labels=top.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Acts per Offices and per Year
#
# Since the data range from 2001 to 2018 there are several office which are closed or merged with others.
# Let see what are:
# - the offices active in the last 2 years
# - the offices not active

# %%
group_office_year = df.groupby(by=[df['UFFICIO_DG'], df['DATA_ATTO'].dt.year])['CODICE_PRATICA'].count()

# %% [markdown]
# If we unstack the grouped data we can see what are the years of activity of the offices.

# %%
df_office_year = group_office_year.unstack()
df_office_year
# Out:
# DATA_ATTO                                             2000    2001    2002  \
# UFFICIO_DG
# 01025                                                  NaN  1083.0   884.0
# 01027                                                  NaN   472.0   505.0
# 01923                                                241.0   264.0   320.0
# 01928                                                711.0   666.0   697.0
# 01931                                               1582.0     NaN     NaN
# 01934                                               1346.0  1168.0  1126.0
# 01937                                               1638.0  1654.0  1723.0
# 01943                                                860.0   942.0   894.0
# 01946                                                638.0   849.0   918.0
# 02090                                                622.0   431.0   296.0
# ALTRI UFFICI                                         148.0   198.0   206.0
# D.G.  AVVOCATURA                               ...     NaN     NaN     NaN
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVI...     NaN     NaN     NaN
# D.G. PRESIDENZA                                ...     NaN     NaN     NaN
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTI...     NaN     NaN     NaN
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE                NaN     NaN     NaN
# DIREZIONE ATTIVITA' PRODUTTIVE                         NaN     NaN     NaN
# DIREZIONE CULTURA E RICERCA                            NaN     NaN     NaN
# DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE         NaN     NaN     NaN
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SO...     NaN     NaN     NaN
# DIREZIONE GENERALE BILANCIO E FINANZE          ...     NaN     NaN     NaN
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIU...     NaN     NaN     NaN
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITI...     NaN     NaN     NaN
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO              NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ...     NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE MOBILITA', INFRAST...     NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMB...     NaN     NaN     NaN
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI D...     NaN     NaN     NaN
# DIREZIONE GENERALE SVILUPPO ECONOMICO          ...     NaN     NaN     NaN
# DIREZIONE ISTRUZIONE E FORMAZIONE                      NaN     NaN     NaN
# DIREZIONE LAVORO                                       NaN     NaN     NaN
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI         NaN     NaN     NaN
# DIREZIONE PROGRAMMAZIONE E BILANCIO                    NaN     NaN     NaN
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE      NaN     NaN     NaN
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLI...     NaN     NaN     NaN
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO        NaN     NaN     NaN
#
# DATA_ATTO                                             2003    2004    2005  \
# UFFICIO_DG
# 01025                                               1063.0     NaN     NaN
# 01027                                                467.0     NaN     NaN
# 01923                                                260.0     NaN     NaN
# 01928                                                636.0     NaN     NaN
# 01931                                                  NaN     NaN     NaN
# 01934                                               1283.0     NaN     NaN
# 01937                                               2143.0     2.0     NaN
# 01943                                               1137.0     NaN     NaN
# 01946                                                941.0     1.0     NaN
# 02090                                                215.0     NaN     NaN
# ALTRI UFFICI                                         207.0     NaN     NaN
# D.G.  AVVOCATURA                               ...     NaN   267.0   268.0
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVI...     NaN     NaN     NaN
# D.G. PRESIDENZA                                ...     NaN   878.0   722.0
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTI...     NaN     NaN     NaN
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE                NaN     NaN     NaN
# DIREZIONE ATTIVITA' PRODUTTIVE                         NaN     NaN     NaN
# DIREZIONE CULTURA E RICERCA                            NaN     NaN     NaN
# DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE         NaN     NaN     NaN
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SO...     NaN     NaN     NaN
# DIREZIONE GENERALE BILANCIO E FINANZE          ...     NaN   400.0   422.0
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIU...     NaN     NaN     NaN
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITI...     NaN  1199.0  1197.0
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO              NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ...     NaN   979.0   877.0
# DIREZIONE GENERALE POLITICHE MOBILITA', INFRAST...     NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMB...     NaN  2076.0  1808.0
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI D...     NaN     NaN     NaN
# DIREZIONE GENERALE SVILUPPO ECONOMICO          ...     NaN  1501.0  1397.0
# DIREZIONE ISTRUZIONE E FORMAZIONE                      NaN     NaN     NaN
# DIREZIONE LAVORO                                       NaN     NaN     NaN
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI         NaN  1179.0   954.0
# DIREZIONE PROGRAMMAZIONE E BILANCIO                    NaN     NaN     NaN
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE      NaN     NaN     NaN
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLI...     NaN     NaN     NaN
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO        NaN     NaN     NaN
#
# DATA_ATTO                                             2006    2007    2008  \
# UFFICIO_DG
# 01025                                                  NaN     NaN     NaN
# 01027                                                  NaN     NaN     NaN
# 01923                                                  NaN     NaN     NaN
# 01928                                                  NaN     NaN     NaN
# 01931                                                  NaN     NaN     NaN
# 01934                                                  NaN     NaN     NaN
# 01937                                                  NaN     NaN     NaN
# 01943                                                  NaN     NaN     NaN
# 01946                                                  NaN     NaN     NaN
# 02090                                                  NaN     NaN     NaN
# ALTRI UFFICI                                           NaN     NaN     NaN
# D.G.  AVVOCATURA                               ...   226.0   240.0   221.0
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVI...     NaN     NaN     NaN
# D.G. PRESIDENZA                                ...   702.0   676.0   708.0
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTI...     NaN     NaN     NaN
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE                NaN     NaN     NaN
# DIREZIONE ATTIVITA' PRODUTTIVE                         NaN     NaN     NaN
# DIREZIONE CULTURA E RICERCA                            NaN     NaN     NaN
# DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE         NaN     NaN     NaN
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SO...     NaN     NaN     NaN
# DIREZIONE GENERALE BILANCIO E FINANZE          ...   365.0   406.0   421.0
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIU...     NaN     NaN     NaN
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITI...  1038.0  1076.0  1082.0
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO              NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ...   828.0   861.0   872.0
# DIREZIONE GENERALE POLITICHE MOBILITA', INFRAST...     NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMB...  1390.0  1292.0  1248.0
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI D...     NaN     NaN     NaN
# DIREZIONE GENERALE SVILUPPO ECONOMICO          ...  1500.0  1466.0  1443.0
# DIREZIONE ISTRUZIONE E FORMAZIONE                      NaN     NaN     NaN
# DIREZIONE LAVORO                                       NaN     NaN     NaN
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI       765.0   879.0   871.0
# DIREZIONE PROGRAMMAZIONE E BILANCIO                    NaN     NaN     NaN
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE      NaN     NaN     NaN
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLI...     NaN     NaN     NaN
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO        NaN     NaN     NaN
#
# DATA_ATTO                                             2009    2010    2011  \
# UFFICIO_DG
# 01025                                                  NaN     NaN     NaN
# 01027                                                  NaN     NaN     NaN
# 01923                                                  NaN     NaN     NaN
# 01928                                                  NaN     NaN     NaN
# 01931                                                  NaN     NaN     NaN
# 01934                                                  NaN     NaN     NaN
# 01937                                                  NaN     NaN     NaN
# 01943                                                  NaN     NaN     NaN
# 01946                                                  NaN     NaN     NaN
# 02090                                                  NaN     NaN     NaN
# ALTRI UFFICI                                          30.0     NaN     1.0
# D.G.  AVVOCATURA                               ...   217.0   208.0   210.0
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVI...     NaN  1104.0  2594.0
# D.G. PRESIDENZA                                ...   772.0   782.0   700.0
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTI...     NaN     NaN     NaN
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE                NaN     NaN     NaN
# DIREZIONE ATTIVITA' PRODUTTIVE                         NaN     NaN     NaN
# DIREZIONE CULTURA E RICERCA                            NaN     NaN     NaN
# DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE         NaN     NaN     NaN
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SO...     NaN   567.0  1229.0
# DIREZIONE GENERALE BILANCIO E FINANZE          ...   386.0   224.0     NaN
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIU...     NaN     NaN     NaN
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITI...  1283.0   604.0     NaN
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO              NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ...  1035.0   569.0     NaN
# DIREZIONE GENERALE POLITICHE MOBILITA', INFRAST...     NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMB...  1290.0   990.0   832.0
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI D...     NaN     NaN     NaN
# DIREZIONE GENERALE SVILUPPO ECONOMICO          ...  1601.0   816.0     NaN
# DIREZIONE ISTRUZIONE E FORMAZIONE                      NaN     NaN     NaN
# DIREZIONE LAVORO                                       NaN     NaN     NaN
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI       700.0   889.0   947.0
# DIREZIONE PROGRAMMAZIONE E BILANCIO                    NaN     NaN     NaN
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE      NaN     NaN     NaN
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLI...     NaN     NaN     NaN
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO        NaN     NaN     NaN
#
# DATA_ATTO                                             2012    2013    2014  \
# UFFICIO_DG
# 01025                                                  NaN     NaN     NaN
# 01027                                                  NaN     NaN     NaN
# 01923                                                  NaN     NaN     NaN
# 01928                                                  NaN     NaN     NaN
# 01931                                                  NaN     NaN     NaN
# 01934                                                  NaN     NaN     NaN
# 01937                                                  NaN     NaN     NaN
# 01943                                                  NaN     NaN     NaN
# 01946                                                  NaN     NaN     NaN
# 02090                                                  NaN     NaN     NaN
# ALTRI UFFICI                                           NaN     NaN     NaN
# D.G.  AVVOCATURA                               ...   202.0   169.0   201.0
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVI...  2693.0  2728.0  3019.0
# D.G. PRESIDENZA                                ...   747.0   652.0   621.0
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTI...     NaN     NaN     NaN
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE                NaN     NaN     NaN
# DIREZIONE ATTIVITA' PRODUTTIVE                         NaN     NaN     NaN
# DIREZIONE CULTURA E RICERCA                            NaN     NaN     NaN
# DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE         NaN     NaN     NaN
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SO...  1367.0  1090.0  1134.0
# DIREZIONE GENERALE BILANCIO E FINANZE          ...     NaN     NaN     NaN
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIU...     NaN     NaN     NaN
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITI...     NaN     NaN     NaN
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO              NaN    48.0    50.0
# DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ...     NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE MOBILITA', INFRAST...     NaN   224.0   276.0
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMB...   762.0   132.0     NaN
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI D...     NaN    71.0    34.0
# DIREZIONE GENERALE SVILUPPO ECONOMICO          ...     NaN     NaN     NaN
# DIREZIONE ISTRUZIONE E FORMAZIONE                      NaN     NaN     NaN
# DIREZIONE LAVORO                                       NaN     NaN     NaN
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI       754.0   638.0   656.0
# DIREZIONE PROGRAMMAZIONE E BILANCIO                    NaN     NaN     NaN
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE      NaN     NaN     NaN
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLI...     NaN   336.0   656.0
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO        NaN     3.0    50.0
#
# DATA_ATTO                                             2015    2016    2017  \
# UFFICIO_DG
# 01025                                                  NaN     NaN     NaN
# 01027                                                  NaN     NaN     NaN
# 01923                                                  NaN     NaN     NaN
# 01928                                                  NaN     NaN     NaN
# 01931                                                  NaN     NaN     NaN
# 01934                                                  NaN     NaN     NaN
# 01937                                                  NaN     NaN     NaN
# 01943                                                  NaN     NaN     NaN
# 01946                                                  NaN     NaN     NaN
# 02090                                                  NaN     NaN     NaN
# ALTRI UFFICI                                           NaN     NaN     NaN
# D.G.  AVVOCATURA                               ...   285.0   254.0   357.0
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVI...  1688.0     NaN     NaN
# D.G. PRESIDENZA                                ...   330.0     NaN     NaN
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTI...    53.0   142.0   132.0
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE              358.0  4325.0  6388.0
# DIREZIONE ATTIVITA' PRODUTTIVE                       287.0   567.0   753.0
# DIREZIONE CULTURA E RICERCA                          141.0   277.0   262.0
# DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE       112.0  1619.0  2812.0
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SO...  1362.0  1236.0  1156.0
# DIREZIONE GENERALE BILANCIO E FINANZE          ...     NaN     NaN     NaN
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIU...   131.0   313.0   258.0
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITI...     NaN     NaN     NaN
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO             18.0     NaN     NaN
# DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ...     NaN     NaN     NaN
# DIREZIONE GENERALE POLITICHE MOBILITA', INFRAST...   306.0   347.0   396.0
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMB...     NaN     NaN     NaN
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI D...     NaN     NaN     NaN
# DIREZIONE GENERALE SVILUPPO ECONOMICO          ...     NaN     NaN     NaN
# DIREZIONE ISTRUZIONE E FORMAZIONE                    420.0  1728.0  1838.0
# DIREZIONE LAVORO                                       NaN   639.0   542.0
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI       611.0   751.0   751.0
# DIREZIONE PROGRAMMAZIONE E BILANCIO                   79.0   163.0   160.0
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE    104.0   186.0   139.0
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLI...   379.0  2384.0  3409.0
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO       89.0   126.0   156.0
#
# DATA_ATTO                                             2018
# UFFICIO_DG
# 01025                                                  NaN
# 01027                                                  NaN
# 01923                                                  NaN
# 01928                                                  NaN
# 01931                                                  NaN
# 01934                                                  NaN
# 01937                                                  NaN
# 01943                                                  NaN
# 01946                                                  NaN
# 02090                                                  NaN
# ALTRI UFFICI                                           NaN
# D.G.  AVVOCATURA                               ...    53.0
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVI...     NaN
# D.G. PRESIDENZA                                ...     NaN
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTI...    24.0
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE             1157.0
# DIREZIONE ATTIVITA' PRODUTTIVE                       117.0
# DIREZIONE CULTURA E RICERCA                           23.0
# DIREZIONE DIFESA DEL SUOLO E PROTEZIONE CIVILE       516.0
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SO...   137.0
# DIREZIONE GENERALE BILANCIO E FINANZE          ...     NaN
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIU...    40.0
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITI...     NaN
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO              NaN
# DIREZIONE GENERALE POLITICHE FORMATIVE, BENI E ...     NaN
# DIREZIONE GENERALE POLITICHE MOBILITA', INFRAST...    47.0
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMB...     NaN
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI D...     NaN
# DIREZIONE GENERALE SVILUPPO ECONOMICO          ...     NaN
# DIREZIONE ISTRUZIONE E FORMAZIONE                    270.0
# DIREZIONE LAVORO                                     114.0
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI        99.0
# DIREZIONE PROGRAMMAZIONE E BILANCIO                   24.0
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE     18.0
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLI...   449.0
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO       18.0

# %% [markdown]
# ### Replace office id with names
#
# Let us merge the index with the name of the offices.

# %%
df_office = pd.read_json('../data/strutture_processed.json')
df_office['ID'] = df_office['ID'].astype(str)

# %%
id_office_map = df_office.set_index(df_office['ID']).drop(['ID'], axis=1).to_dict()['NOME']

# %% [markdown]
# We check what are the offices that do not have a match

# %%
not_matched = []
matched = []
matched_id_name = {}

for i in df_office_year.index:
    if i in id_office_map:
        matched.append(id_office_map[i])
        matched_id_name[i] = id_office_map[i]
    else:
        not_matched.append(i)

# %% [markdown]
# From the name of the offices it is interesting to see that there are:
# - offices that changed the name
# - there are some abbreviations
#
# we will create a replacement map to deal with these problems

# %%
matched_id_name
# Out:
# {}

# %%
to_replace = {
    '50001': '50115',
    '50069': '50115',
    '50102': '50115',
    '50083': '50004',
    '50079': '50116',
    '50118': '50202',
    '50121': '50201'
}

# %% [markdown]
# - We can replace the offices with wrong names
# - we reaplace the codes with the canonical names of the offices

# %%
df_replaced = df
df_replaced['UFFICIO_DG'] = df['UFFICIO_DG'].replace(to_replace)

# %%
df= df_replaced.replace(matched_id_name)

# %%
df.head()
# Out:
#                 CODICE_PRATICA  DATA_ATTO DESCRIZIONE_TIPO_PRATICA ID_TIPO  \
# 0  20160140002016AD00000017201 2016-12-19       Atto dei dirigenti     ADN
# 1  20160140012016AD00000017466 2016-12-21       Atto dei dirigenti     ADN
# 2  20160140022016AD00000017198 2016-12-19       Atto dei dirigenti     ADN
# 3  20160140032016AD00000017208 2016-12-19       Atto dei dirigenti     ADN
# 4  20160140042016AD00000017268 2016-12-20       Atto dei dirigenti     ADN
#
#   ID_TIPO_PRATICA                             LINK_CONTENUTO_BINARIO  \
# 0             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 1             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 2             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 3             MON  http://www.regione.toscana.it/bancadati/atti/C...
# 4             MON  http://www.regione.toscana.it/bancadati/atti/C...
#
#                                              OGGETTO PERSONA  STATUS  \
# 0  DGR 968/07 e s.m.i. Accreditamento degli organ...  013910       2
# 1  REG. CEE 2080/92 - AIUTI ALLE MISURE FORESTALI...  005595       2
# 2  Servizi autorizzati ex art.14 L.R. 42/98 "Norm...  019075       2
# 3  L.R. 1/2006, DCR 3/2012, L.R. 1/2015 art.29, c...  020415       2
# 4  L.R. n. 87/1997 - Pubblicazione sul BURT dell'...  010826       2
#
#   UFFICIO_AC                                         UFFICIO_DG UFFICIO_SE  \
# 0      00000                  DIREZIONE ISTRUZIONE E FORMAZIONE      05873
# 1      00000            DIREZIONE AGRICOLTURA E SVILUPPO RURALE      05015
# 2      00000  DIREZIONE GENERALE POLITICHE MOBILITA', INFRAS...      04838
# 3      00000            DIREZIONE AGRICOLTURA E SVILUPPO RURALE      05018
# 4      00000  DIREZIONE DIRITTI DI CITTADINANZA E COESIONE S...      05895
#
#                                           DETAIL_URL
# 0  http://www.regione.toscana.it/bancadati/atti/D...
# 1  http://www.regione.toscana.it/bancadati/atti/D...
# 2  http://www.regione.toscana.it/bancadati/atti/D...
# 3  http://www.regione.toscana.it/bancadati/atti/D...
# 4  http://www.regione.toscana.it/bancadati/atti/D...

# %% [markdown]
# Now let's group the acts per Ufficio DG. Also in this case we can see there are some office that around 14000 acts.

# %%
print('distribution acts per Ufficio DG')
acts_per_office = df.groupby([df['UFFICIO_DG']])['CODICE_PRATICA'].count()
acts_per_office = acts_per_office.sort_values(ascending=False)
print('Top 10 \n',acts_per_office[:10])
print('Last 10 \n',acts_per_office[-10:])
# Out:
# distribution acts per Ufficio DG
# Top 10
#  UFFICIO_DG
# D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVILUPPO D    13826
# DIREZIONE AGRICOLTURA E SVILUPPO RURALE                   12228
# DIREZIONE GENERALE POLITICHE TERRITORIALI E AMBIENTALI    11820
# DIREZIONE ORGANIZZAZIONE E SISTEMI INFORMATIVI            11444
# DIREZIONE GENERALE SVILUPPO ECONOMICO                      9724
# DIREZIONE DIRITTI DI CITTADINANZA E COESIONE SOCIALE       9278
# D.G. PRESIDENZA                                            8290
# POLITICHE AMBIENTALI, ENERGIA E CAMBIAMENTI CLIMATICI      7613
# DIREZIONE GENERALE DIRITTO ALLA SALUTE E POLITICHE DI      7479
# 01937                                                      7160
# Name: CODICE_PRATICA, dtype: int64
# Last 10
#  UFFICIO_DG
# 01923                                                           1085
# ALTRI UFFICI                                                     790
# DIREZIONE GENERALE DIREZIONE GENERALE DELLA GIUNTA REGIONALE     742
# DIREZIONE CULTURA E RICERCA                                      703
# DIREZIONE URBANISTICA, CASA E POLITICHE ABITATIVE                447
# SEGRETERIE ORGANI POLITICI UFFICIO DI GABINETTO                  442
# DIREZIONE PROGRAMMAZIONE E BILANCIO                              426
# DIREZIONE AFFARI LEGISLATIVI, GIURIDICI ED ISTITUZIONALI         351
# DIREZIONE GENERALE GOVERNO DEL TERRITORIO                        116
# DIREZIONE GENERALE SEGRETERIE ORGANI POLITICI DELLA GIUNTA       105
# Name: CODICE_PRATICA, dtype: int64

# %% [markdown]
# As final exploration it would be interesting to see for the top person what is the distributions of acts per year

# %%
df_person = df[df['PERSONA'] == '005549']
acts_per_year_person = df_person.groupby([df_person['DATA_ATTO'].dt.year])['CODICE_PRATICA'].count()

fig, ax = plt.subplots()
sns.barplot(acts_per_year_person.index, acts_per_year_person.values, palette="BuGn_d", 
            ax=ax, order=acts_per_year_person.index)
label_rotation(ax, 45)
fig.set_size_inches(10,6)
plt.show(fig)

# %% [markdown]
# Moreover, we can see that he works for different officess

# %%
df_person = df[df['PERSONA'] == '005549']
df_person['UFFICIO_DG'].unique()
# Out:
# array(['DIREZIONE AGRICOLTURA E SVILUPPO RURALE',
#        'DIREZIONE GENERALE SVILUPPO ECONOMICO                 ',
#        "D.G. COMPETITIVITA' DEL SISTEMA REGIONALE E SVILUPPO D", '01934',
#        'ALTRI UFFICI'], dtype=object)

# %% [markdown]
# Here we can see that apart 2016 and 2017 this person did in average the same number of acts.
#
# It would be interesting to see the contribution of each person per office in order to spot:
# - when a person moves from one office to another
# - Who is in charge of an office (considering that if a person is in charge sign more acts than the others)
#
# ## Next Step
#
# After the data exploration the next steps of this notebook is to write a classification model able to predict the office that writes the act given the text in the subject (Oggetto) attribute.

# %%
pd.to_pickle(df,'../data/atti-dirigenti-processed.pkl')
